# %% [markdown]
# # Lecture 10.14
#
# #### Leo Wheeler
#
# ## Objectives
#
# 1. Discuss the different ways to read in data
# 2. Review Lab6
#
# ## Using the `read` method

# %%
file_ID = open("/srv/data/lecture_data/AAPL_closing_price.csv")

# %%
my_file = file_ID.read()

# %% [markdown]
# - The `read` reads in the entire file as a single string

# %%
my_file
# Out:
# '0.513393\n0.504464\n0.633929\n0.616071\n0.569196\n0.553571\n0.584821\n0.504464\n0.513393\n0.455357\n0.433036\n0.473214\n0.457589\n0.397321\n0.459821\n0.441964\n0.473214\n0.497768\n0.446429\n0.517857\n0.506696\n0.5\n0.491071\n0.560268\n0.591518\n0.564732\n0.580357\n0.540179\n0.520089\n0.459821\n0.397321\n0.462054\n0.428571\n0.446429\n0.450893\n0.408482\n0.359375\n0.359375\n0.363839\n0.350446\n0.316964\n0.254464\n0.294643\n0.332589\n0.325893\n0.339286\n0.357143\n0.321429\n0.323661\n0.339286\n0.337054\n0.339286\n0.334821\n0.408482\n0.390625\n0.395089\n0.354911\n0.357143\n0.370536\n0.363839\n0.352679\n0.334821\n0.334821\n0.325893\n0.296875\n0.272321\n0.296875\n0.290179\n0.316964\n0.3125\n0.301339\n0.274554\n0.263393\n0.290179\n0.261161\n0.254464\n0.25\n0.234375\n0.238839\n0.229911\n0.236607\n0.214286\n0.203125\n0.236607\n0.252232\n0.241071\n0.21875\n0.234375\n0.263393\n0.301339\n0.328125\n0.323661\n0.316964\n0.323661\n0.330357\n0.419643\n0.410714\n0.462054\n0.453125\n0.537946\n0.578125\
# ...

# %%
type(my_file)
# Out:
# str

# %%
len(my_file)
# Out:
# 18473

# %%
file_ID.close()

# %% [markdown]
# ## The `readline` method

# %%
file_ID = open("/srv/data/lecture_data/AAPL_closing_price.csv")

# %%
file_ID.readline()
# Out:
# '0.513393\n'

# %%
file_ID.close()

# %% [markdown]
# ## The `readlines` method

# %%
file_ID = open("/srv/data/lecture_data/AAPL_closing_price.csv")

# %%
file_ID.readlines()
# Out:
# ['0.513393\n',
#  '0.504464\n',
#  '0.633929\n',
#  '0.616071\n',
#  '0.569196\n',
#  '0.553571\n',
#  '0.584821\n',
#  '0.504464\n',
#  '0.513393\n',
#  '0.455357\n',
#  '0.433036\n',
#  '0.473214\n',
#  '0.457589\n',
#  '0.397321\n',
#  '0.459821\n',
#  '0.441964\n',
#  '0.473214\n',
#  '0.497768\n',
#  '0.446429\n',
#  '0.517857\n',
#  '0.506696\n',
#  '0.5\n',
#  '0.491071\n',
#  '0.560268\n',
#  '0.591518\n',
#  '0.564732\n',
#  '0.580357\n',
#  '0.540179\n',
#  '0.520089\n',
#  '0.459821\n',
#  '0.397321\n',
#  '0.462054\n',
#  '0.428571\n',
#  '0.446429\n',
#  '0.450893\n',
#  '0.408482\n',
#  '0.359375\n',
#  '0.359375\n',
#  '0.363839\n',
#  '0.350446\n',
#  '0.316964\n',
#  '0.254464\n',
#  '0.294643\n',
#  '0.332589\n',
#  '0.325893\n',
#  '0.339286\n',
#  '0.357143\n',
#  '0.321429\n',
#  '0.323661\n',
#  '0.339286\n',
#  '0.337054\n',
#  '0.339286\n',
#  '0.334821\n',
#  '0.408482\n',
#  '0.390625\n',
#  '0.395089\n',
#  '0.354911\n',
#  '0.357143\n',
#  '0.370536\n',
# ...

# %%
file_ID.close()

# %% [markdown]
# ## Recap
#
# We looked at 4 ways to read in information:
#
# 1. Using `read`
#     - Reads entire file as a single string
# 2. Using `readline`
#     - Reads line by line, as a string
# 3. Using `readlines`
#     - Reads the entire file as a list of string objects formed by individual lines
# 4. Iterating over the file using a `for` loop
#     - for line in FILE_ID:
#         do stuff!
